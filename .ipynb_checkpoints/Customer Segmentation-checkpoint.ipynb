# %%
#imports and dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
#ignore warnings
warnings.filterwarnings('ignore')

# %%
#read csv file
hotelDF = pd.read_csv('clean_hotel_second.csv')
hotelDF
# Out:
#       Booking_ID  no_of_adults  no_of_children  required_car_parking_space  \
# 0       INN00001             2               0                           0
# 1       INN00002             2               0                           0
# 2       INN00003             1               0                           0
# 3       INN00004             2               0                           0
# 4       INN00005             2               0                           0
# ...          ...           ...             ...                         ...
# 35590   INN36271             3               0                           0
# 35591   INN36272             2               0                           0
# 35592   INN36273             2               0                           0
# 35593   INN36274             2               0                           0
# 35594   INN36275             2               0                           0
#
#        lead_time  arrival_year  arrival_month  arrival_date  \
# ...

# %%
#select the features for clustering
features = hotelDF[['lead_time','total_nights', 'total_price','no_of_adults','no_of_children', 'repeated_guest']].values

# %%
#standardize features
stanScaler = StandardScaler()
scaledFeatures = stanScaler.fit_transform(features)

# %%
#calculate inertia of each cluster number 
#and graph the elbow method
clusterRange = range(1,11)

inertia = []

for k in clusterRange:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(features)
    inertia.append(kmeans.inertia_)
    
plt.figure(figsize=(8, 5))
plt.plot(clusterRange, inertia, 'bo-', markersize=8)
plt.xlabel('Cluster Numbers')
plt.ylabel('Inertia')
plt.title('Elbow Method to Choose Cluster Number')
plt.show()

# %%
# Apply PCA to reduce dimensions
pca = PCA(n_components=2)  # You can adjust the number of components based on your analysis
principalComponents = pca.fit_transform(scaledFeatures)

# Optionally, check explained variance ratio to decide on components
print(pca.explained_variance_ratio_)

# You can use the principal components for clustering instead of the scaled features
# Out:
# [0.33751566 0.19272425]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Apply KMeans with a range of cluster sizes to use the elbow method
inertia = []
silhouette_scores = []
cluster_range = range(2, 11)

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(principalComponents)
    
    inertia.append(kmeans.inertia_)
    silhouette_avg = silhouette_score(principalComponents, kmeans.labels_)
    silhouette_scores.append(silhouette_avg)

# Plotting the elbow method
plt.figure(figsize=(10, 5))
plt.plot(cluster_range, inertia, 'bo-')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal Clusters')
plt.show()

# Plotting the silhouette scores
plt.figure(figsize=(10, 5))
plt.plot(cluster_range, silhouette_scores, 'ro-')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores For Various Clusters')
plt.show()

# %%
# KMeans cluster with four clusters
kMeans = KMeans(n_clusters=4, random_state=42)
hotelDF['cluster'] = kmeans.fit_predict(scaledFeatures)

# %%
#view first five rows of dataframe
hotelDF[['lead_time','total_nights', 'total_price','no_of_adults','no_of_children', 'repeated_guest', 'cluster']].head()

# %%
#k-clustering of leadtime vs total price
x_feature = 'lead_time'
y_feature = 'total_price'

# Plot the clusters
plt.figure(figsize=(10, 6))
plt.scatter(hotelDF[x_feature], hotelDF[y_feature], c=hotelDF['cluster'], cmap='rainbow', marker='o', edgecolor='k')
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.title('K-means Clustering (k=4)')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
# create a family size feature for more K-clustering
hotelDF['family_size'] = hotelDF['no_of_adults'] + hotelDF['no_of_children']
hotelDF

# %%
x_feature = 'family_size'
y_feature = 'total_nights'

# Plot the clusters
plt.figure(figsize=(10, 6))
plt.scatter(hotelDF[x_feature], hotelDF[y_feature], c=hotelDF['cluster'], cmap='rainbow', marker='o', edgecolor='k')
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.title('K-means Clustering (k=4)')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
# Get mean, median, and other statistics for certain features
clusterSummary = hotelDF.groupby('cluster').agg({
    'family_size': ['mean', 'median', 'min', 'max'],
    'total_nights': ['mean', 'median', 'min', 'max'],
    'total_price': ['mean', 'median', 'min', 'max'],
    'lead_time': ['mean', 'median', 'min', 'max'],
    'no_of_special_requests': ['mean', 'median', 'min', 'max'],
    'no_of_adults': ['mean', 'median', 'min', 'max'],
    'no_of_children': ['mean', 'median', 'min', 'max'],
    'no_of_previous_cancellations': ['mean', 'median', 'min', 'max'],
    'no_of_previous_bookings_not_canceled': ['mean', 'median', 'min', 'max'],
}).reset_index()

# %%
sns.boxplot(x='cluster', y='total_price', data=hotelDF)
plt.title('Total Price Disbursement Across Clusters')
plt.show()

# %%
sns.boxplot(x='cluster', y='lead_time', data=hotelDF)
plt.title('Lead Time Disbursement Across Clusters')
plt.show()

# %%
sns.boxplot(x='cluster', y='total_nights', data=hotelDF)
plt.title('Total Nights Disbursement Across Clusters')
plt.show()
